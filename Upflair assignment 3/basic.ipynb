# %%
import pandas as pd

# %%
df=pd.read_csv('cust_satisfaction.csv')

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df.head(10) ## head uper ke 5 element
# Out:
#    Gender      Customer Type   Type of Travel     Class  \
# 0    Male     Loyal Customer  Personal Travel  Eco Plus
# 1    Male  disloyal Customer  Business travel  Business
# 2  Female     Loyal Customer  Business travel  Business
# 3  Female     Loyal Customer  Business travel  Business
# 4    Male     Loyal Customer  Business travel  Business
# 5  Female     Loyal Customer  Personal Travel       Eco
# 6    Male     Loyal Customer  Personal Travel       Eco
# 7  Female     Loyal Customer  Business travel  Business
# 8  Female     Loyal Customer  Business travel  Business
# 9    Male  disloyal Customer  Business travel       Eco
#
#               satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0  neutral or dissatisfied   13              460                       5
# 1  neutral or dissatisfied   25              235                       1
# 2                satisfied   26             1142                       5
# ...

# %%
df.tail()
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 103899  neutral or dissatisfied   23              192                       2
# 103900                satisfied   49             2347                       5
# 103901  neutral or dissatisfied   30             1995                       4
# 103902  neutral or dissatisfied   22             1000                       1
# 103903  neutral or dissatisfied   27             1723                       1
#
#         Baggage handling  Cleanliness  Departure Delay in Minutes  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103904 non-null  object
#  1   Customer Type               103904 non-null  object
#  2   Type of Travel              103904 non-null  object
#  3   Class                       103904 non-null  object
#  4   satisfaction                103904 non-null  object
#  5   Age                         103904 non-null  int64
#  6   Flight Distance             103904 non-null  int64
#  7   Inflight entertainment      103904 non-null  int64
#  8   Baggage handling            103904 non-null  int64
#  9   Cleanliness                 103904 non-null  int64
#  10  Departure Delay in Minutes  103904 non-null  int64
#  11  Arrival Delay in Minutes    103594 non-null  float64
# dtypes: float64(1), int64(6), object(5)
# ...

# %%
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction',
#        'Age', 'Flight Distance', 'Inflight entertainment', 'Baggage handling',
#        'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  Age  Flight Distance  Inflight entertainment  \
# count  103904.000000    103904.000000           103904.000000
# mean       39.379706      1189.448375                3.358158
# std        15.114964       997.147281                1.332991
# min         7.000000        31.000000                0.000000
# 25%        27.000000       414.000000                2.000000
# 50%        40.000000       843.000000                4.000000
# 75%        51.000000      1743.000000                4.000000
# max        85.000000      4983.000000                5.000000
#
#        Baggage handling    Cleanliness  Departure Delay in Minutes  \
# count     103904.000000  103904.000000               103904.000000
# mean           3.631833       3.286351                   14.815618
# std            1.180903       1.312273                   38.230901
# min            1.000000       0.000000                    0.000000
# 25%            3.000000       2.000000                    0.000000
# ...

# %%
df.isnull()
# Out:
#         Gender  Customer Type  Type of Travel  Class  satisfaction    Age  \
# 0        False          False           False  False         False  False
# 1        False          False           False  False         False  False
# 2        False          False           False  False         False  False
# 3        False          False           False  False         False  False
# 4        False          False           False  False         False  False
# ...        ...            ...             ...    ...           ...    ...
# 103899   False          False           False  False         False  False
# 103900   False          False           False  False         False  False
# 103901   False          False           False  False         False  False
# 103902   False          False           False  False         False  False
# 103903   False          False           False  False         False  False
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# ...

# %%
df.isnull().sum()
# Out:
# Gender                          0
# Customer Type                   0
# Type of Travel                  0
# Class                           0
# satisfaction                    0
# Age                             0
# Flight Distance                 0
# Inflight entertainment          0
# Baggage handling                0
# Cleanliness                     0
# Departure Delay in Minutes      0
# Arrival Delay in Minutes      310
# dtype: int64

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103899    False
# 103900    False
# 103901    False
# 103902    False
# 103903    False
# Length: 103904, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 172

# %%
df.drop_duplicates(inplace=True) ###

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# df.dropna()
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df['Customer Type']
# Out:
# 0            Loyal Customer
# 1         disloyal Customer
# 2            Loyal Customer
# 3            Loyal Customer
# 4            Loyal Customer
#                 ...
# 103899    disloyal Customer
# 103900       Loyal Customer
# 103901    disloyal Customer
# 103902    disloyal Customer
# 103903       Loyal Customer
# Name: Customer Type, Length: 103732, dtype: object

# %%
df['Customer Type'].unique()
# Out:
# array(['Loyal Customer', 'disloyal Customer'], dtype=object)

# %%
df['Customer Type'].value_counts()
# Out:
# Customer Type
# Loyal Customer       84778
# disloyal Customer    18954
# Name: count, dtype: int64

# %%
df['Class'].value_counts()
# Out:
# Class
# Business    49555
# Eco         46684
# Eco Plus     7493
# Name: count, dtype: int64

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df =df.drop(['Class','Customer Type'], axis=1 )   #1 coloums 0 row

# %%
df
# Out:
#         Gender   Type of Travel             satisfaction  Age  \
# 0         Male  Personal Travel  neutral or dissatisfied   13
# 1         Male  Business travel  neutral or dissatisfied   25
# 2       Female  Business travel                satisfied   26
# 3       Female  Business travel  neutral or dissatisfied   25
# 4         Male  Business travel                satisfied   61
# ...        ...              ...                      ...  ...
# 103899  Female  Business travel  neutral or dissatisfied   23
# 103900    Male  Business travel                satisfied   49
# 103901    Male  Business travel  neutral or dissatisfied   30
# 103902  Female  Business travel  neutral or dissatisfied   22
# 103903    Male  Business travel  neutral or dissatisfied   27
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# 0                   460                       5                 4
# 1                   235                       1                 3
# ...

# %%
cat_col =df.select_dtypes(include='object')

# %%
cat_col
# Out:
#         Gender   Type of Travel             satisfaction
# 0         Male  Personal Travel  neutral or dissatisfied
# 1         Male  Business travel  neutral or dissatisfied
# 2       Female  Business travel                satisfied
# 3       Female  Business travel  neutral or dissatisfied
# 4         Male  Business travel                satisfied
# ...        ...              ...                      ...
# 103899  Female  Business travel  neutral or dissatisfied
# 103900    Male  Business travel                satisfied
# 103901    Male  Business travel  neutral or dissatisfied
# 103902  Female  Business travel  neutral or dissatisfied
# 103903    Male  Business travel  neutral or dissatisfied
#
# [103732 rows x 3 columns]

# %%
num_cal=df.select_dtypes(exclude='object')

# %%
num_cal
# Out:
#         Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 0        13              460                       5                 4
# 1        25              235                       1                 3
# 2        26             1142                       5                 4
# 3        25              562                       2                 3
# 4        61              214                       3                 4
# ...     ...              ...                     ...               ...
# 103899   23              192                       2                 4
# 103900   49             2347                       5                 5
# 103901   30             1995                       4                 4
# 103902   22             1000                       1                 1
# 103903   27             1723                       1                 4
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# ...

# %%
df.dtypes
# Out:
# Gender                         object
# Type of Travel                 object
# satisfaction                   object
# Age                             int64
# Flight Distance                 int64
# Inflight entertainment          int64
# Baggage handling                int64
# Cleanliness                     int64
# Departure Delay in Minutes      int64
# Arrival Delay in Minutes      float64
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import mean_squared_error, accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df['Arrival Delay in Minutes'].fillna(df['Arrival Delay in Minutes'].median(), inplace=True)
# Out:
# C:\Users\yashs\AppData\Local\Temp\ipykernel_16484\2584395854.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Arrival Delay in Minutes'].fillna(df['Arrival Delay in Minutes'].median(), inplace=True)

# %%
label_cols = ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction']
le = LabelEncoder()
for col in label_cols:
    df[col] = le.fit_transform(df[col])

# %%
X_lin = df.drop(['Flight Distance'], axis=1)
y_lin = df['Flight Distance']

# %%
X_train_lin, X_test_lin, y_train_lin, y_test_lin = train_test_split(X_lin, y_lin, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
X_train_lin = scaler.fit_transform(X_train_lin)
X_test_lin = scaler.transform(X_test_lin)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train_lin, y_train_lin)
# Out:
# LinearRegression()

# %%
y_pred_lin = lin_reg.predict(X_test_lin)
print("\nLinear Regression - RMSE:", np.sqrt(mean_squared_error(y_test_lin, y_pred_lin)))
# Out:
# Linear Regression - RMSE: 864.1964340002685

# %%
X_log = df.drop(['satisfaction'], axis=1)
y_log = df['satisfaction']

# %%
X_train_log, X_test_log, y_train_log, y_test_log = train_test_split(x_log, y_log, test_size=0.2, random_state=42)

# %%
X_train_log = scaler.fit_transform(X_train_log)
X_test_log = scaler.transform(X_test_log)

# %%
log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(X_train_log, y_train_log)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred_log = log_reg.predict(X_test_log)
print("\n📊 Logistic Regression - Accuracy:", accuracy_score(y_test_log, y_pred_log))
print("\nConfusion Matrix:\n", confusion_matrix(y_test_log, y_pred_log))
print("\nClassification Report:\n", classification_report(y_test_log, y_pred_log))
# Out:
# 📊 Logistic Regression - Accuracy: 0.8362446465521389
#
# Confusion Matrix:
#  [[10138  1575]
#  [ 1828  7240]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86     11713
#            1       0.82      0.80      0.81      9068
#
#     accuracy                           0.84     20781
#    macro avg       0.83      0.83      0.83     20781
# weighted avg       0.84      0.84      0.84     20781
